# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("petrol_consumption.csv")
data
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
print(data.head())
print(data.tail())
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 43         7.0            3745            2611                         0.508
# 44         6.0            5215            2302                         0.672
# 45         9.0            4476            3942                         0.571
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Petrol_tax                    48 non-null     float64
#  1   Average_income                48 non-null     int64
#  2   Paved_Highways                48 non-null     int64
#  3   Population_Driver_licence(%)  48 non-null     float64
#  4   Petrol_Consumption            48 non-null     int64
# dtypes: float64(2), int64(3)
# memory usage: 2.0 KB

# %%
print(data.count())
# Out:
# Petrol_tax                      48
# Average_income                  48
# Paved_Highways                  48
# Population_Driver_licence(%)    48
# Petrol_Consumption              48
# dtype: int64

# %%
data.isna().sum()
# Out:
# Petrol_tax                      0
# Average_income                  0
# Paved_Highways                  0
# Population_Driver_licence(%)    0
# Petrol_Consumption              0
# dtype: int64

# %%
data.describe()
# Out:
#        Petrol_tax  Average_income  Paved_Highways  \
# count   48.000000       48.000000       48.000000
# mean     7.668333     4241.833333     5565.416667
# std      0.950770      573.623768     3491.507166
# min      5.000000     3063.000000      431.000000
# 25%      7.000000     3739.000000     3110.250000
# 50%      7.500000     4298.000000     4735.500000
# 75%      8.125000     4578.750000     7156.000000
# max     10.000000     5342.000000    17782.000000
#
#        Population_Driver_licence(%)  Petrol_Consumption
# count                     48.000000           48.000000
# mean                       0.570333          576.770833
# std                        0.055470          111.885816
# min                        0.451000          344.000000
# 25%                        0.529750          509.500000
# 50%                        0.564500          568.500000
# 75%                        0.595250          632.750000
# max                        0.724000          968.000000

# %%
model = LinearRegression()
model = model.fit(data[["Petrol_tax"]], data[["Petrol_Consumption"]])
model = LinearRegression().fit(data[["Petrol_tax"]], data[["Petrol_Consumption"]])

# %%
print('Intercept :', model.intercept_)
# Out:
# Intercept : [984.00762756]

# %%
print('Slope :', model.coef_)
# Out:
# Slope : [[-53.10629788]]

# %%
#Prediction of Brain Weight = 15
model.predict([[15]])
# Out:
# array([[187.41315939]])

# %%
# Petrol consumption

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Petrol_tax                    48 non-null     float64
#  1   Average_income                48 non-null     int64
#  2   Paved_Highways                48 non-null     int64
#  3   Population_Driver_licence(%)  48 non-null     float64
#  4   Petrol_Consumption            48 non-null     int64
# dtypes: float64(2), int64(3)
# memory usage: 2.0 KB

# %%
data.isna().sum()
# Out:
# Petrol_tax                      0
# Average_income                  0
# Paved_Highways                  0
# Population_Driver_licence(%)    0
# Petrol_Consumption              0
# dtype: int64

# %%
data.describe()
# Out:
#        Petrol_tax  Average_income  Paved_Highways  \
# count   48.000000       48.000000       48.000000
# mean     7.668333     4241.833333     5565.416667
# std      0.950770      573.623768     3491.507166
# min      5.000000     3063.000000      431.000000
# 25%      7.000000     3739.000000     3110.250000
# 50%      7.500000     4298.000000     4735.500000
# 75%      8.125000     4578.750000     7156.000000
# max     10.000000     5342.000000    17782.000000
#
#        Population_Driver_licence(%)  Petrol_Consumption
# count                     48.000000           48.000000
# mean                       0.570333          576.770833
# std                        0.055470          111.885816
# min                        0.451000          344.000000
# 25%                        0.529750          509.500000
# 50%                        0.564500          568.500000
# 75%                        0.595250          632.750000
# max                        0.724000          968.000000

# %%
data.count()
# Out:
# Petrol_tax                      48
# Average_income                  48
# Paved_Highways                  48
# Population_Driver_licence(%)    48
# Petrol_Consumption              48
# dtype: int64

# %%
data.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
model = LinearRegression()
model = model.fit(data[["Petrol_Consumption"]], data[["Average_income"]])

# %%
model.predict(data[["Petrol_Consumption"]])
# Out:
# array([[4286.73915931],
#        [4308.08054196],
#        [4261.63165032],
#        [4446.17184142],
#        [4451.19334321],
#        [4392.19069708],
#        [4534.04812289],
#        [4379.63694259],
#        [4383.40306893],
#        [4340.72030365],
#        [4237.77951678],
#        [4374.61544079],
#        [4306.82516651],
#        [4328.16654915],
#        [4255.35477307],
#        [4168.73386705],
#        [4208.90588144],
#        [4069.55920653],
#        [3879.99751363],
#        [4162.4569898 ],
#        [4151.15861075],
#        [4287.99453476],
#        [4383.40306893],
#        [4279.20690662],
#        [4388.42457073],
#        [4255.35477307],
#        [4241.54564313],
#        [4173.75536885],
#        [4245.31176948],
#        [4295.52678746],
#        [4249.07789582],
#        [4270.41927847],
#        [4241.54564313],
#        [4177.52149519],
#        [4354.52943359],
#        [4157.435488  ],
#        [4162.4569898 ],
#        [4082.11296102],
# ...

# %%
print('Intercept :', model.intercept_)
# Out:
# Intercept : [4965.89727756]

# %%
sns.boxplot(data["Petrol_tax"], data["Petrol_Consumption"])
# Out:
# d:\datascience\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Petrol_tax', ylabel='Petrol_Consumption'>

# %%
#Scatter plot
plt.scatter(data["Petrol_tax"], data["Petrol_Consumption"], color="purple")

plt.title("Scatter Petrol")
plt.xlabel("Petrol_tax")
plt.ylabel("Petrol_Consumption")
plt.show()
